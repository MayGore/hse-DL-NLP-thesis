# %%
gpt_answers.json
 {
    'answers': [
        {
            'nationality': 'china',
            'education': 'middle',
            'model': 'Gpt5',
            'texts': [
                {
                    'original': 'kjhghjkjhg',
                    'response': 'uygfghjuygf'
                },
                {
                    'original': 'kjhghjkjhg',
                    'response': 'uygfghjuygf'
                }
            ]
        },
        {
            'nationality': 'china',
            'education': 'higher',
            'model': 'Gpt5',
            'texts': [
                {
                    'original': 'kjhghjkjhg',
                    'response': 'uygfghjuygf'
                },
                {
                    'original': 'kjhghjkjhg',
                    'response': 'uygfghjuygf'
                }
            ]
        }
    ]
}

# %%
text_originals.json
{
    'texts': [
        {
            'text': 'kjhgfghjk',
            'word_count': 727,
            'mistake_count': 10
        },
        {
            'text': 'kjhgfghjk',
            'word_count': 727,
            'mistake_count': 10
        }
    ]
}

# %%
bios.json
{
    'bios': [
        {
            'nationality': '',
            'education': '',
            'full bio': ''
        },
        {
            'nationality': '',
            'education': '',
            'full bio': ''
        },
    ]
}
